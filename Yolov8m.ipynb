# %%
from IPython import display
display.clear_output()
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.231 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5310.5/8062.4 GB disk)

# %%
from ultralytics import YOLO

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="nINzPN28KOi4OKajKf5X")
project = rf.workspace("dip-project-ud7ul").project("asl-nzdfr")
dataset = project.version(7).download("yolov8")

# %%
# !yolo task=detect mode=train model=yolov8m.pt data={dataset}/data.yaml epochs=30 imgsz=640 plots=True batch=16
# Out:
# ...
# 100%|███████████████████████████████████████| 49.7M/49.7M [00:00<00:00, 217MB/s]
# Ultralytics YOLOv8.0.231 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# ...
